# %% [markdown]
# <a href="https://colab.research.google.com/github/Learnermeet/Data_Analysis_and_Visualization_Practice/blob/main/mean-median-mode%5Cmean_median_mode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics as st
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/data.csv')
data
# Out:
#        Sr. No.  Height(Inches)  Weight(Pounds)
# 0            1        65.78331        112.9925
# 1            2        71.51521        136.4873
# 2            3        69.39874        153.0269
# 3            4        68.21660        142.3354
# 4            5        67.78781        144.2971
# ...        ...             ...             ...
# 24995    24996        69.50215        118.0312
# 24996    24997        64.54826        120.1932
# 24997    24998        64.69855        118.2655
# 24998    24999        67.52918        132.2682
# 24999    25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sr. No.         25000 non-null  int64
#  1   Height(Inches)  25000 non-null  float64
#  2   Weight(Pounds)  25000 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 586.1 KB

# %%
data_sorted = data.sort_values(by=['Height(Inches)', 'Weight(Pounds)'], ascending=True)
data_sorted.head()
# Out:
#        Sr. No.  Height(Inches)  Weight(Pounds)
# 13971    13972        60.27836       110.11380
# 2651      2652        60.61265        88.04646
# 20608    20609        60.80620       113.91450
# 5641      5642        60.86340       106.19390
# 12031    12032        60.86977       108.86330

# %%
# Calculate the mean of the first 50 elements for 'Height(Inches)' and 'Weight(Pounds)'
mean_height_first_50 = data['Height(Inches)'].head(50).mean()
mean_weight_first_50 = data['Weight(Pounds)'].head(50).mean()

print(f"Mean of first 50 'Height(Inches)': {mean_height_first_50}")
print(f"Mean of first 50 'Weight(Pounds)': {mean_weight_first_50}")
# Out:
# Mean of first 50 'Height(Inches)': 68.0527616
# Mean of first 50 'Weight(Pounds)': 128.8429362

# %%
# Calculate the mean of all elements for 'Height(Inches)' and 'Weight(Pounds)'
mean_height_all = data['Height(Inches)'].mean()
mean_weight_all = data['Weight(Pounds)'].mean()

print(f"Mean of all 'Height(Inches)': {mean_height_all}")
print(f"Mean of all 'Weight(Pounds)': {mean_weight_all}")
# Out:
# Mean of all 'Height(Inches)': 67.99311359679999
# Mean of all 'Weight(Pounds)': 127.07942116080001

# %%
# Calculate the median of the first 50 elements for 'Height(Inches)' and 'Weight(Pounds)'
median_height_first_50 = data['Height(Inches)'].head(50).median()
median_weight_first_50 = data['Weight(Pounds)'].head(50).median()

print(f"Median of first 50 'Height(Inches)': {median_height_first_50}")
print(f"Median of first 50 'Weight(Pounds)': {median_weight_first_50}")

# Calculate the median of all elements for 'Height(Inches)' and 'Weight(Pounds)'
median_height_all = data['Height(Inches)'].median()
median_weight_all = data['Weight(Pounds)'].median()

print(f"Median of all 'Height(Inches)': {median_height_all}")
print(f"Median of all 'Weight(Pounds)': {median_weight_all}")
# Out:
# Median of first 50 'Height(Inches)': 67.86822
# Median of first 50 'Weight(Pounds)': 129.5025
# Median of all 'Height(Inches)': 67.9957
# Median of all 'Weight(Pounds)': 127.15775

# %%
# Calculate the mode for 'Height(Inches)' and 'Weight(Pounds)'
mode_height = data['Height(Inches)'].mode()[0] # .mode() can return multiple values, take the first
mode_weight = data['Weight(Pounds)'].mode()[0]

print(f"Mode of 'Height(Inches)': {mode_height}")
print(f"Mode of 'Weight(Pounds)': {mode_weight}")
# Out:
# Mode of 'Height(Inches)': 65.65796
# Mode of 'Weight(Pounds)': 124.7975

# %%
plt.figure(figsize=(7, 6))

# Histogram for Height(Inches)
sns.histplot(data['Height(Inches)'], kde=True, color='skyblue')
plt.title('Distribution of Height (Inches)')
plt.xlabel('Height (Inches)')
plt.ylabel('Frequency')

# Add lines for mean, median, and mode for Height(Inches)
mean_height = data['Height(Inches)'].mean()
median_height = data['Height(Inches)'].median()
mode_height = data['Height(Inches)'].mode()[0]

plt.axvline(mean_height, color='red', linestyle='dashed', linewidth=1.5, label=f'Mean: {mean_height:.2f}')
plt.axvline(median_height, color='green', linestyle='dashed', linewidth=1.5, label=f'Median: {median_height:.2f}')
plt.axvline(mode_height, color='purple', linestyle='dashed', linewidth=1.5, label=f'Mode: {mode_height:.2f}')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 6))

# Histogram for Weight(Pounds)
sns.histplot(data['Weight(Pounds)'], kde=True, color='lightcoral')
plt.title('Distribution of Weight (Pounds)')
plt.xlabel('Weight (Pounds)')
plt.ylabel('Frequency')

# Add lines for mean, median, and mode for Weight(Pounds)
mean_weight = data['Weight(Pounds)'].mean()
median_weight = data['Weight(Pounds)'].median()
mode_weight = data['Weight(Pounds)'].mode()[0] # .mode() can return multiple values, take the first

plt.axvline(mean_weight, color='red', linestyle='dashed', linewidth=1.5, label=f'Mean: {mean_weight:.2f}')
plt.axvline(median_weight, color='green', linestyle='dashed', linewidth=1.5, label=f'Median: {median_weight:.2f}')
plt.axvline(mode_weight, color='purple', linestyle='dashed', linewidth=1.5, label=f'Mode: {mode_weight:.2f}')
plt.legend()
plt.tight_layout()
plt.show()
