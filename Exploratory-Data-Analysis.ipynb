# %% [markdown]
# <a href="https://colab.research.google.com/github/Learnermeet/Data_Analysis_and_Visualization_Practice/blob/main/Exploratory-Data-Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/train.csv')
data
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5847 entries, 0 to 5846
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5847 non-null   int64
#  1   Name               5847 non-null   object
#  2   Location           5847 non-null   object
#  3   Year               5847 non-null   int64
#  4   Kilometers_Driven  5847 non-null   int64
#  5   Fuel_Type          5847 non-null   object
#  6   Transmission       5847 non-null   object
#  7   Owner_Type         5847 non-null   object
#  8   Mileage            5845 non-null   object
#  9   Engine             5811 non-null   object
#  10  Power              5811 non-null   object
#  11  Seats              5809 non-null   float64
#  12  New_Price          815 non-null    object
#  13  Price              5847 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 639.6+ KB

# %%
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 1              46000    Petrol       Manual      First    13 km/kg  1199 CC
# 2              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 3              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
# 4              86999    Diesel       Manual      First  23.08 kmpl  1461 CC
#
#        Power  Seats  New_Price  Price
# 0  126.2 bhp    5.0        NaN  12.50
# ...

# %%
data.tail()
# Out:
#       Unnamed: 0                      Name   Location  Year  \
# 5842        6014          Maruti Swift VDI      Delhi  2014
# 5843        6015  Hyundai Xcent 1.1 CRDi S     Jaipur  2015
# 5844        6016     Mahindra Xylo D4 BSIV     Jaipur  2012
# 5845        6017        Maruti Wagon R VXI    Kolkata  2013
# 5846        6018     Chevrolet Beat Diesel  Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 5842              27365    Diesel       Manual      First   28.4 kmpl
# 5843             100000    Diesel       Manual      First   24.4 kmpl
# 5844              55000    Diesel       Manual     Second   14.0 kmpl
# 5845              46000    Petrol       Manual      First   18.9 kmpl
# 5846              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine     Power  Seats  New_Price  Price
# 5842  1248 CC    74 bhp    5.0  7.88 Lakh   4.75
# 5843  1120 CC    71 bhp    5.0        NaN   4.00
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Location', 'Year', 'Kilometers_Driven',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power',
#        'Seats', 'New_Price', 'Price'],
#       dtype='object')

# %%
data =data.drop(['Engine'],axis =1)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Location', 'Year', 'Kilometers_Driven',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Mileage', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
data.shape
# Out:
# (5847, 13)

# %%
data.nunique()
# Out:
# Unnamed: 0           5847
# Name                 1804
# Location               11
# Year                   22
# Kilometers_Driven    3019
# Fuel_Type               3
# Transmission            2
# Owner_Type              4
# Mileage               419
# Power                 361
# Seats                   8
# New_Price             534
# Price                1366
# dtype: int64

# %%
data.isnull()
# Out:
#       Unnamed: 0   Name  Location   Year  Kilometers_Driven  Fuel_Type  \
# 0          False  False     False  False              False      False
# 1          False  False     False  False              False      False
# 2          False  False     False  False              False      False
# 3          False  False     False  False              False      False
# 4          False  False     False  False              False      False
# ...          ...    ...       ...    ...                ...        ...
# 5842       False  False     False  False              False      False
# 5843       False  False     False  False              False      False
# 5844       False  False     False  False              False      False
# 5845       False  False     False  False              False      False
# 5846       False  False     False  False              False      False
#
#       Transmission  Owner_Type  Mileage  Power  Seats  New_Price  Price
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Power                  36
# Seats                  38
# New_Price            5032
# Price                   0
# dtype: int64

# %%
from datetime import date
import datetime as dt
date.today().year
# Out:
# 2026

# %%
data['Car_Age'] = date.today().year - data['Year']
data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           2                      Honda Jazz V     Chennai  2011
# 2           3                 Maruti Ertiga VDI     Chennai  2012
# 3           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           6            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage      Power  \
# 0              41000    Diesel       Manual      First  19.67 kmpl  126.2 bhp
# 1              46000    Petrol       Manual      First    13 km/kg   88.7 bhp
# 2              87000    Diesel       Manual      First  20.77 kmpl  88.76 bhp
# 3              40670    Diesel    Automatic     Second   15.2 kmpl  140.8 bhp
# 4              86999    Diesel       Manual      First  23.08 kmpl   63.1 bhp
#
#    Seats  New_Price  Price  Car_Age
# 0    5.0        NaN  12.50       11
# ...

# %%
data['Brand'] = data.Name.str.split().str.get(0)
data
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
data['Model'] = data.Name.str.split().str.get(1)+data.Name.str.split().str.get(2)
data
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
data[['Name','Brand','Model']]
# Out:
#                                   Name      Brand        Model
# 0     Hyundai Creta 1.6 CRDi SX Option    Hyundai     Creta1.6
# 1                         Honda Jazz V      Honda        JazzV
# 2                    Maruti Ertiga VDI     Maruti    ErtigaVDI
# 3      Audi A4 New 2.0 TDI Multitronic       Audi        A4New
# 4               Nissan Micra Diesel XV     Nissan  MicraDiesel
# ...                                ...        ...          ...
# 5842                  Maruti Swift VDI     Maruti     SwiftVDI
# 5843          Hyundai Xcent 1.1 CRDi S    Hyundai     Xcent1.1
# 5844             Mahindra Xylo D4 BSIV   Mahindra       XyloD4
# 5845                Maruti Wagon R VXI     Maruti       WagonR
# 5846             Chevrolet Beat Diesel  Chevrolet   BeatDiesel
#
# [5847 rows x 3 columns]

# %%
data.Brand.unique()
# Out:
# array(['Hyundai', 'Honda', 'Maruti', 'Audi', 'Nissan', 'Toyota',
#        'Volkswagen', 'Tata', 'Land', 'Mitsubishi', 'Renault',
#        'Mercedes-Benz', 'BMW', 'Mahindra', 'Ford', 'Porsche', 'Datsun',
#        'Jaguar', 'Volvo', 'Chevrolet', 'Skoda', 'Mini', 'Fiat', 'Jeep',
#        'Ambassador', 'Isuzu', 'ISUZU', 'Force', 'Bentley', 'Lamborghini'],
#       dtype=object)

# %%
data.Brand.nunique()
# Out:
# 30

# %%
searchfor = ['Isuzu','ISUZU','Mini','Land']
data[data.Brand.isin(searchfor)]
# Out:
#       Unnamed: 0                                       Name    Location  Year  \
# 11            13           Land Rover Range Rover 2.2L Pure       Delhi  2014
# 12            14             Land Rover Freelander 2 TD4 SE        Pune  2012
# 168          176                   Mini Countryman Cooper D      Jaipur  2017
# 183          191        Land Rover Range Rover 2.2L Dynamic  Coimbatore  2018
# 219          228                  Mini Cooper Convertible S       Kochi  2017
# ...          ...                                        ...         ...   ...
# 5365        5518                       Mini Cooper 3 DOOR S       Kochi  2016
# 5376        5530                 Land Rover Freelander 2 SE       Kochi  2014
# 5384        5539  Land Rover Discovery Sport SD4 HSE Luxury       Delhi  2016
# 5390        5545            Land Rover Range Rover Sport SE       Delhi  2014
# 5809        5979                    ISUZU D-MAX V-Cross 4X4      Jaipur  2017
#
# ...

# %%
data['Brand'].replace({"ISUZU": "Isuzu","Mini": "Mini Cooper","Land": "Land Rover"}, inplace=True)
data
# Out:
# /tmp/ipython-input-614013967.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Brand'].replace({"ISUZU": "Isuzu","Mini": "Mini Cooper","Land": "Land Rover"}, inplace=True)
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# ...

# %%
data.Brand.unique()
# Out:
# array(['Hyundai', 'Honda', 'Maruti', 'Audi', 'Nissan', 'Toyota',
#        'Volkswagen', 'Tata', 'Land Rover', 'Mitsubishi', 'Renault',
#        'Mercedes-Benz', 'BMW', 'Mahindra', 'Ford', 'Porsche', 'Datsun',
#        'Jaguar', 'Volvo', 'Chevrolet', 'Skoda', 'Mini Cooper', 'Fiat',
#        'Jeep', 'Ambassador', 'Isuzu', 'Force', 'Bentley', 'Lamborghini'],
#       dtype=object)

# %%
data.Brand.nunique()
# Out:
# 29

# %%
searchfor = ['Isuzu','ISUZU','Mini','Land']
data[data.Brand.isin(searchfor)]
# Out:
#       Unnamed: 0                     Name    Location  Year  \
# 2810        2900            Isuzu MUX 4WD      Jaipur  2017
# 3511        3624  ISUZU D-MAX V-Cross 4X4  Coimbatore  2018
# 5809        5979  ISUZU D-MAX V-Cross 4X4      Jaipur  2017
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type    Mileage  \
# 2810              34429    Diesel    Automatic      First  13.8 kmpl
# 3511              20422    Diesel       Manual      First  12.4 kmpl
# 5809              25000    Diesel       Manual      First  12.4 kmpl
#
#            Power  Seats   New_Price  Price  Car_Age  Brand         Model
# 2810  174.57 bhp    7.0  33.68 Lakh  20.00        9  Isuzu        MUX4WD
# 3511     134 bhp    5.0         NaN  16.09        8  Isuzu  D-MAXV-Cross
# 5809     134 bhp    5.0         NaN   8.00        9  Isuzu  D-MAXV-Cross

# %%
data.describe()
# Out:
#         Unnamed: 0         Year  Kilometers_Driven        Seats        Price  \
# count  5847.000000  5847.000000       5.847000e+03  5809.000000  5847.000000
# mean   3013.181461  2013.448435       5.841013e+04     5.286452     9.653742
# std    1736.398890     3.194949       9.237971e+04     0.806668    11.275966
# min       1.000000  1998.000000       1.710000e+02     2.000000     0.440000
# 25%    1509.500000  2012.000000       3.346750e+04     5.000000     3.550000
# 50%    3015.000000  2014.000000       5.257600e+04     5.000000     5.750000
# 75%    4517.500000  2016.000000       7.249050e+04     5.000000    10.250000
# max    6018.000000  2019.000000       6.500000e+06    10.000000   160.000000
#
#            Car_Age
# count  5847.000000
# mean     12.551565
# std       3.194949
# min       7.000000
# 25%      10.000000
# 50%      12.000000
# 75%      14.000000
# max      28.000000

# %%
data.describe().T
# Out:
#                     count          mean           std      min       25%  \
# Unnamed: 0         5847.0   3013.181461   1736.398890     1.00   1509.50
# Year               5847.0   2013.448435      3.194949  1998.00   2012.00
# Kilometers_Driven  5847.0  58410.134599  92379.712368   171.00  33467.50
# Seats              5809.0      5.286452      0.806668     2.00      5.00
# Price              5847.0      9.653742     11.275966     0.44      3.55
# Car_Age            5847.0     12.551565      3.194949     7.00     10.00
#
#                         50%       75%        max
# Unnamed: 0          3015.00   4517.50     6018.0
# Year                2014.00   2016.00     2019.0
# Kilometers_Driven  52576.00  72490.50  6500000.0
# Seats                  5.00      5.00       10.0
# Price                  5.75     10.25      160.0
# Car_Age               12.00     14.00       28.0

# %%
data.describe(include='all').T
# Out:
#                     count unique                     top  freq          mean  \
# Unnamed: 0         5847.0    NaN                     NaN   NaN   3013.181461
# Name                 5847   1804  Mahindra XUV500 W8 2WD    49           NaN
# Location             5847     11                  Mumbai   762           NaN
# Year               5847.0    NaN                     NaN   NaN   2013.448435
# Kilometers_Driven  5847.0    NaN                     NaN   NaN  58410.134599
# Fuel_Type            5847      3                  Diesel  3161           NaN
# Transmission         5847      2                  Manual  4135           NaN
# Owner_Type           5847      4                   First  4811           NaN
# Mileage              5845    419               18.9 kmpl   172           NaN
# Power                5811    361                  74 bhp   235           NaN
# Seats              5809.0    NaN                     NaN   NaN      5.286452
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0             int64
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Power                 object
# Seats                float64
# New_Price             object
# Price                float64
# Car_Age                int64
# Brand                 object
# Model                 object
# dtype: object

# %%
cat_cols = data.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type',
#        'Mileage', 'Power', 'New_Price', 'Brand', 'Model'],
#       dtype='object')

# %%
num_cols = data.select_dtypes(include=np.number).columns.tolist()
num_cols
# Out:
# ['Unnamed: 0', 'Year', 'Kilometers_Driven', 'Seats', 'Price', 'Car_Age']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
x_axis = data['Year']
y_axis = data['Price']
plt.title('Year vs Price')
plt.xlabel('Year')
plt.ylabel('Price')

plt.bar(x_axis,y_axis)
plt.show()
plt.scatter(x_axis,y_axis)
plt.show()

# %%
x_axis = data['Kilometers_Driven']
y_axis = data['Price']
plt.title('Kilometers_Driven vs Price')
plt.xlabel('Kilometers_Driven')
plt.ylabel('Price')

plt.scatter(x_axis,y_axis)
plt.show()

# %%
x_axis = data['Car_Age']
y_axis = data['Price']
plt.title('Car_Age vs Price')
plt.xlabel('Car_Age')
plt.ylabel('Price')

plt.scatter(x_axis,y_axis)
plt.show()
